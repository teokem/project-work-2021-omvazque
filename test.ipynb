# %% [markdown]
# ## My personal reasons to choose this project
# My research as a PhD student at the University of Lund, Sweden focuses in analysing data recorded by the ALICE experiment at CERN. From distributions constructed with real data, I apply statistical methods to study the phenomena from proton-proton and heavy-ion collisions and try to connect our observations with the underlying physics mechanisms.
# However, I am also interested in applying my skills as an experimental physicist to investigate phenomena outside of academia, such as, the evolution of COVID-19 pandemic or to the industrial and finantial sectors. Having said that the purpose of the Jupyter notebook is to analyse the data provided by the Johns Hopkins Center for Systems Science and Engineering [JHUCSSE](https://github.com/CSSEGISandData) of the Novel Coronavirus (COVID-19) Cases in the United States.

# %% [markdown]
# ## Abstract of project
#
# In the [JHUCSSE](https://github.com/CSSEGISandData) repository one can find daily reports of the number of Confirmed, Deaths, Recovered, etc. cases. For example, one can find the file `04-12-2020.csv` associated to report from the 12th of April of 2020. In this notebook, I am interested in the Confirmed and Deaths cases as a function of the state. In addition only data dating from the 12th of April 2020 to the 31st of March 2021 will be taken into account.

# %% [markdown]
# ## Import required packages

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams.update({'axes.labelsize': 30, 'axes.titlesize': 30,'axes.labelweight': 'bold','axes.titleweight': 'bold'})
plt.rcParams.update({'xtick.labelsize': 25, 'ytick.labelsize': 25})
plt.rcParams.update({'lines.markersize': 13})
plt.rcParams.update({'legend.fontsize': 25,'legend.frameon': False,'legend.framealpha':0.0,'legend.loc': 'upper center'})

# %% [markdown]
# One efficient tool to mage large amount of data is the **pandas** library. The code below declares lists associated to different months (`frame_apr_2020, frame_may_2020, etc.`). The `pd.read_csv()` function can be used to read and store data frames into the previously defined lists.

# %%
path = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us'
Columns = ['Province_State','Country_Region','Last_Update','Lat','Long_','Confirmed','Deaths','Recovered','Active','FIPS','Incident_Rate','People_Tested','People_Hospitalized','Mortality_Rate']
Names = ['Province_State','Country_Region','Last_Update','Lat','Long_','Confirmed','Deaths','Recovered','Active','FIPS','Incident_Rate','People_Tested','People_Hospitalized','Mortality_Rate']

year = ['2020', '2021']
month = ['01','02','03','04','05','06','07','08','09','10','11','12']
days_2020 = [31,29,31,30,31,30,31,31,30,31,30,31]
days_2021 = [31,28,31,30,31,30,31,31,30,31,30,31]

start_day = 10

frame_apr_2020 = []
frame_may_2020 = []
frame_jun_2020 = []
frame_jul_2020 = []
frame_aug_2020 = []
frame_sep_2020 = []
frame_oct_2020 = []
frame_nov_2020 = []
frame_dec_2020 = []
frame_jan_2021 = []
frame_feb_2021 = []
frame_mar_2021 = []

for d in range(days_2020[month.index('04')]):
    if(d > start_day):
        frame_apr_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'04',d+1,'2020'),header=0,usecols=Columns,names=Names))

for d in range(days_2020[month.index('05')]):
    if(d < 9):
        frame_may_2020.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'05',d+1,'2020'),header=0,usecols=Columns,names=Names))
    else:
        frame_may_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'05',d+1,'2020'),header=0,usecols=Columns,names=Names))
        
for d in range(days_2020[month.index('06')]):
    if(d < 9):
        frame_jun_2020.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'06',d+1,'2020'),header=0,usecols=Columns,names=Names))
    else:
        frame_jun_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'06',d+1,'2020'),header=0,usecols=Columns,names=Names))

for d in range(days_2020[month.index('07')]):
    if(d < 9):
        frame_jul_2020.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'07',d+1,'2020'),header=0,usecols=Columns,names=Names))
    else:
        frame_jul_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'07',d+1,'2020'),header=0,usecols=Columns,names=Names))

for d in range(days_2020[month.index('08')]):
    if(d < 9):
        frame_aug_2020.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'08',d+1,'2020'),header=0,usecols=Columns,names=Names))
    else:
        frame_aug_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'08',d+1,'2020'),header=0,usecols=Columns,names=Names))

for d in range(days_2020[month.index('09')]):
    if(d < 9):
        frame_sep_2020.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'09',d+1,'2020'),header=0,usecols=Columns,names=Names))
    else:
        frame_sep_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'09',d+1,'2020'),header=0,usecols=Columns,names=Names))

for d in range(days_2020[month.index('10')]):
    if(d < 9):
        frame_oct_2020.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'10',d+1,'2020'),header=0,usecols=Columns,names=Names))
    else:
        frame_oct_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'10',d+1,'2020'),header=0,usecols=Columns,names=Names))

for d in range(days_2020[month.index('11')]):
    if(d < 9):
        frame_nov_2020.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'11',d+1,'2020'),header=0,usecols=Columns,names=Names))
    else:
        frame_nov_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'11',d+1,'2020'),header=0,usecols=Columns,names=Names))

for d in range(days_2020[month.index('12')]):
    if(d < 9):
        frame_dec_2020.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'12',d+1,'2020'),header=0,usecols=Columns,names=Names))
    else:
        frame_dec_2020.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'12',d+1,'2020'),header=0,usecols=Columns,names=Names))

for d in range(days_2021[month.index('01')]):
    if(d < 9):
        frame_jan_2021.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'01',d+1,'2021'),header=0,usecols=Columns,names=Names))
    else:
        frame_jan_2021.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'01',d+1,'2021'),header=0,usecols=Columns,names=Names))
        
for d in range(days_2021[month.index('02')]):
    if(d < 9):
        frame_feb_2021.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'02',d+1,'2021'),header=0,usecols=Columns,names=Names))
    else:
        frame_feb_2021.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'02',d+1,'2021'),header=0,usecols=Columns,names=Names))

for d in range(days_2021[month.index('03')]):
    if(d < 9):
        frame_mar_2021.append(pd.read_csv('{}/{}-0{}-{}.csv'.format(path,'03',d+1,'2021'),header=0,usecols=Columns,names=Names))
    else:
        frame_mar_2021.append(pd.read_csv('{}/{}-{}-{}.csv'.format(path,'03',d+1,'2021'),header=0,usecols=Columns,names=Names))

# %% [markdown]
# By running `frame_apr_2020[11].head()` in a code cell one can see the different type of information in the data frame.

# %% [markdown]
# I am interested in the number of **Confirmed** and **Deaths** cases as a function of the different states (Texas, California, Florida, etc.).
# In the code below one can use the `pd.pivot_table` function to select only data of our interest. For instance the `Province_State` can be used as the row index and the values in the columns will correspond to the **Confirmed** and **Deaths** cases.
# The number of cases up to a particular month is taken from its last day. For example `frame_jul_2020[-1]` will return the number of cases until the 30th of July of 2020.

# %%
columns_names = ['apr_2020', 'may_2020','jun_2020', 'jul_2020','aug_2020', 'sep_2020','oct_2020', 'nov_2020','dec_2020', 'jan_2021', 'feb_2021','mar_2021']
Values = ['Confirmed','Deaths','Recovered','Active']

pivot_apr_2020 = pd.pivot_table(frame_apr_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_may_2020 = pd.pivot_table(frame_may_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_jun_2020 = pd.pivot_table(frame_jun_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_jul_2020 = pd.pivot_table(frame_jul_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_aug_2020 = pd.pivot_table(frame_aug_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_sep_2020 = pd.pivot_table(frame_sep_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_oct_2020 = pd.pivot_table(frame_oct_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_nov_2020 = pd.pivot_table(frame_nov_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_dec_2020 = pd.pivot_table(frame_dec_2020[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_jan_2021 = pd.pivot_table(frame_jan_2021[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_feb_2021 = pd.pivot_table(frame_feb_2021[-1],values=Values,index=['Province_State'],aggfunc='sum')
pivot_mar_2021 = pd.pivot_table(frame_mar_2021[-1],values=Values,index=['Province_State'],aggfunc='sum')

# %% [markdown]
# The line below illustrates how to save a table using the `pandas.DataFrame.to_csv()` function. In fact, the saved `pivot_table_31March2021.csv` file contains only the number of confirmed, deaths, recovered and active cases. The `index` was included setting `index=True` and the table is stored in the current working directory. In this jupyter notebook the main interest is to visualise some quantities instead of generating data, therefore, the saved fiile will not be used in thee remaining of the notebook.

# %%
pivot_mar_2021.to_csv('pivot_table_31March2021.csv',index=True)

# %% [markdown]
# In the code below the aggregated number of Confirmed cases is plotted as a function of the state. One can see that until the 31st of March of 2021 California is the state with most of the Confirmed cases. In addition, in the period between November 2020 to January 2021 the majority of the new cases were reported.

# %%
variable_to_plot = 'Confirmed'
plt.figure(figsize=(30,8))
ax = plt.axes()

ax.plot(pivot_apr_2020.index.values,pivot_apr_2020[variable_to_plot].values,marker='o',linestyle="None",label='Apr 2020')
ax.plot(pivot_may_2020.index.values,pivot_may_2020[variable_to_plot].values,marker='v',linestyle="None",label='May 2020')
ax.plot(pivot_jun_2020.index.values,pivot_jun_2020[variable_to_plot].values,marker='<',linestyle="None",label='June 2020')
ax.plot(pivot_jul_2020.index.values,pivot_jul_2020[variable_to_plot].values,marker='>',linestyle="None",label='July 2020')
ax.plot(pivot_aug_2020.index.values,pivot_aug_2020[variable_to_plot].values,marker='^',linestyle="None",label='August 2020')
ax.plot(pivot_sep_2020.index.values,pivot_sep_2020[variable_to_plot].values,marker='8',linestyle="None",label='September 2020')
ax.plot(pivot_oct_2020.index.values,pivot_oct_2020[variable_to_plot].values,marker='s',linestyle="None",label='October 2020')
ax.plot(pivot_nov_2020.index.values,pivot_nov_2020[variable_to_plot].values,marker='p',linestyle="None",label='November 2020')
ax.plot(pivot_dec_2020.index.values,pivot_dec_2020[variable_to_plot].values,marker='P',linestyle="None",label='December 2020')
ax.plot(pivot_jan_2021.index.values,pivot_jan_2021[variable_to_plot].values,marker='*',linestyle="None",label='January 2021')
ax.plot(pivot_feb_2021.index.values,pivot_feb_2021[variable_to_plot].values,marker='D',linestyle="None",label='February 2021')
ax.plot(pivot_mar_2021.index.values,pivot_mar_2021[variable_to_plot].values,marker='h',linestyle="None",label='March 2021')

plt.title("{} cases of COVID-19 in different states".format(variable_to_plot))
plt.xlabel("States")
plt.xticks(rotation=90)
ax.legend(ncol=3)
plt.show()

# %% [markdown]
# In the code below the aggregated number of Deaths due to COVID-19 is plotted as a function of the state. It can be observed that California, New York and Texas concentrate the majority of deaths.

# %%
variable_to_plot = 'Deaths'
plt.figure(figsize=(25,8))
ax = plt.axes()

ax.plot(pivot_apr_2020.index.values,pivot_apr_2020[variable_to_plot].values,marker='o',linestyle="None",label='Apr 2020')
ax.plot(pivot_may_2020.index.values,pivot_may_2020[variable_to_plot].values,marker='v',linestyle="None",label='May 2020')
ax.plot(pivot_jun_2020.index.values,pivot_jun_2020[variable_to_plot].values,marker='<',linestyle="None",label='June 2020')
ax.plot(pivot_jul_2020.index.values,pivot_jul_2020[variable_to_plot].values,marker='>',linestyle="None",label='July 2020')
ax.plot(pivot_aug_2020.index.values,pivot_aug_2020[variable_to_plot].values,marker='^',linestyle="None",label='August 2020')
ax.plot(pivot_sep_2020.index.values,pivot_sep_2020[variable_to_plot].values,marker='8',linestyle="None",label='September 2020')
ax.plot(pivot_oct_2020.index.values,pivot_oct_2020[variable_to_plot].values,marker='s',linestyle="None",label='October 2020')
ax.plot(pivot_nov_2020.index.values,pivot_nov_2020[variable_to_plot].values,marker='p',linestyle="None",label='November 2020')
ax.plot(pivot_dec_2020.index.values,pivot_dec_2020[variable_to_plot].values,marker='P',linestyle="None",label='December 2020')
ax.plot(pivot_jan_2021.index.values,pivot_jan_2021[variable_to_plot].values,marker='*',linestyle="None",label='January 2021')
ax.plot(pivot_feb_2021.index.values,pivot_feb_2021[variable_to_plot].values,marker='D',linestyle="None",label='February 2021')
ax.plot(pivot_mar_2021.index.values,pivot_mar_2021[variable_to_plot].values,marker='h',linestyle="None",label='March 2021')

plt.title("{} due to COVID-19 in different states".format(variable_to_plot))
plt.xlabel("States")
plt.xticks(rotation=90)
plt.ylim([0, 9.5e4])
ax.legend(ncol=3)

# %% [markdown]
# Below, a pandas series is created. The indexes correspond to the names of the states while the values are the number of inhabitants.
# The ratio of confirmed and deaths cases to the number of inhabitants is computed using the function `pandas.Series1.divide(pandas.Series2)`. These ratios are plotted in bar charts below to compare with the fraction of confirmed and deaths out of the total number of registered cases.

# %%
population_arr = np.array([4903000,732000,56000,7279000,3018000,39512000,5759000,3565000,974000,39512000,706000,21477000,10617000,39512000,168000,1416000,1787000,12671000,6732000,3155000,2913000,4468000,4649000,1344000,6046000,6893000,9987000,5640000,2976000,6137000,1069000,1934000,3080000,1360000,8882000,2097000,19453000,10488000,762000,51000,11689000,3957000,4218000,12802000,3194000,1059000,5149000,885000,6829000,28996000,3206000,624000,106000,8536000,7615000,1792000,5822000,579000])
population_ser = pd.Series(population_arr,pivot_apr_2020.index.values)
ratio_confirmed_to_population = pivot_mar_2021["Confirmed"].divide(population_ser)
ratio_deaths_to_population = pivot_mar_2021["Deaths"].divide(population_ser)

# %% [markdown]
# In the code below the `pd.crosstab` function is used to normalize the data and to plot the fraction of confirmed cases out of the total number cases (blue bars) as a function of the State until the 31st of March of 2021. It is observed that California has the largest fraction of confirmed cases with more that 10%. In addition, in red the number of confirmed cases normalised to the number of inhabitants is plotted. On average the fraction of confirmed cases normalised by the population is found to be around 8%.

# %%
variable_to_plot = 'Confirmed'
co_total = pd.crosstab(index=frame_mar_2021[-1].Province_State,
                       columns=frame_mar_2021[-1]['Country_Region'],values=frame_mar_2021[-1][variable_to_plot],
                       aggfunc='sum',normalize='columns',margins=True,margins_name='Confirmed')

fig = plt.figure(figsize=(25,8))
ax = fig.add_axes([0,0,1,1])

plt.title("Fraction of {} cases of COVID-19 until March 31, 2021".format(variable_to_plot))
plt.xlabel("States")
plt.xticks(rotation=90)

ax.bar(co_total.Confirmed.index.values,ratio_confirmed_to_population,color='red',alpha=0.5,label='Normalised to the number of inhabitants per state')
ax.bar(co_total.Confirmed.index.values,co_total.Confirmed.values,color='blue',alpha=0.5,label='Normalised to the total number of cases')
plt.ylim([0, 0.16])
ax.legend()
plt.show()

# %% [markdown]
# The `pd.crosstab` function is used to normalize the data and to plot the fraction of deaths due to COVID-19 as a function of the State until the 31st of March of 2021 (blue bars). It can be seen that California, New York and Texas accoount for more than 26% of the total deaths. In addition, in red the number of deaths normalised to the number of inhabitants is plotted. On average the fraction of deaths cases normalised by the population is found to be less that 0.15%.

# %%
variable_to_plot = 'Deaths'
de_total = pd.crosstab(index=frame_mar_2021[-1].Province_State,
                       columns=frame_mar_2021[-1]['Country_Region'],values=frame_mar_2021[-1][variable_to_plot],
                       aggfunc='sum',normalize='columns',margins=True,margins_name='Deaths')

fig = plt.figure(figsize=(25,8))
ax = fig.add_axes([0,0,1,1])

plt.title("Fraction of {} due to COVID-19 until March 31, 2021".format(variable_to_plot))
plt.xlabel("States")
plt.xticks(rotation=90)

ax.bar(co_total.Confirmed.index.values,ratio_deaths_to_population,color='red',alpha=0.5,label='Normalised to the number of inhabitants per state')
ax.bar(de_total.Deaths.index.values,de_total.Deaths.values,color='blue',alpha=0.5,label='Normalised to the total number of deaths')
ax.legend()
plt.show()

# %% [markdown]
# The code below uses `subplots` to visualize in a 2-row and 1-column array the fraction of confirmed and deaths cases until the 31st of March of 2021.

# %%
fig,(ax1, ax2) = plt.subplots(nrows=2,ncols=1,sharex=True,figsize=(28, 15))

ax1.plot(co_total,color='red',marker='o',markersize=13,linestyle="-")
ax2.plot(de_total,color='blue',marker='o',markersize=13,linestyle="-")
ax1.set_facecolor('xkcd:white')
ax2.set_facecolor('xkcd:white')

ax1.set_title('Fraction of Confirmed cases of COVID-19 per State until March 31, 2021',fontweight="bold", size=30) # Title
ax2.set_title('Fraction of Deaths due to COVID-19 per State until March 31, 2021',fontweight="bold", size=30) # Title
ax2.title.set_text('Percentage of Deaths due to COVID-19 per State until March 31, 2021')
ax1.tick_params(labelsize=25)
ax2.tick_params(labelsize=25)
ax2.set_xlabel('States', fontsize = 30)

plt.xticks(rotation=90)
fig.patch.set_facecolor('xkcd:white')
plt.show()

# %% [markdown]
# In the code below a pie chart is used to represent the top 5 states with Confirmed cases. California, Texas, Florida, New York and Illinois lead this category. The total remaining is represented as the Rest. At the end of this piece of code, the pie chart is saved as a `png` figure in the current directory.

# %%
plt.style.use('fivethirtyeight')
variable_to_plot = 'Confirmed'
co_total = pd.crosstab(index=frame_mar_2021[-1].Province_State,
                       columns=frame_mar_2021[-1]['Country_Region'],values=frame_mar_2021[-1][variable_to_plot],
                       aggfunc='sum',normalize='columns',margins=True,margins_name='Confirmed')

x = co_total.Confirmed.index.values
y = co_total.Confirmed.values

n = 5
top_values = sorted(y)[-n:]
top_indexes = []
indexes = []
    
for i in top_values:
    top_indexes.append(co_total.index[co_total['Confirmed'] == i].tolist())
    
for i in range(n):
    indexes.append(top_indexes[i][0])

top_values.append(1.0-(np.array(top_values)).sum())
indexes.append('Rest')    

fig1, ax1 = plt.subplots(figsize=(13,8.0))
ax1.pie(x=top_values, labels=indexes,
        autopct='%1.1f%%',shadow=False, startangle=90,normalize=False)
ax1.axis('equal')
fig1.savefig('pie_chart_confirmed.png',dpi=300)
fig1.patch.set_facecolor('xkcd:white')
plt.show()

# %% [markdown]
# In the code below a pie chart is used to represent the top 5 states with Deaths due to COIVD-19. In this category, California, New York, Texas, Florida and Pennsylvania represent about 40% of the total Deaths while the remaining is represented as the Rest.

# %%
#plt.style.use('fivethirtyeight')
variable_to_plot = 'Deaths'
de_total = pd.crosstab(index=frame_mar_2021[-1].Province_State,
                       columns=frame_mar_2021[-1]['Country_Region'],values=frame_mar_2021[-1][variable_to_plot],
                       aggfunc='sum',normalize='columns',margins=True,margins_name=variable_to_plot)


x = de_total.Deaths.index.values
y = de_total.Deaths.values

n = 5
top_values = sorted(y)[-n:]
top_indexes = []
indexes = []
    
for i in top_values:
    top_indexes.append(de_total.index[de_total[variable_to_plot] == i].tolist())
    
for i in range(n):
    indexes.append(top_indexes[i][0])

top_values.append(1.0-(np.array(top_values)).sum())
indexes.append('Rest')    

fig1, ax1 = plt.subplots(figsize=(13,8.0))
ax1.pie(x=top_values, labels=indexes,
        autopct='%1.1f%%',shadow=False, startangle=90,normalize=False)
ax1.axis('equal')
fig1.savefig('pie_chart_deaths.png',dpi=300)
fig1.patch.set_facecolor('xkcd:white')
plt.show()

# %% [markdown]
# ## Summary
#
# In this Jupyter notebook, I have accessed to the data related to the COVID-19 pandemic in the United States and collected by [JHUCSSE](https://github.com/CSSEGISandData). The main interest was to visualise the number of **Confirmed** and **Deaths** as a function of the states.
# It was found that California, Texas and Florida amount to 28% of the total number of confirmed cases. However when normalising the number of confirmed cases to the number of inhabitants per state, on average 8% of the population was tested positive.
# When analysing the fraction of deaths, California, New York and Texas represent a fraction of 28.5% of the total number of deaths. However when normalising the number of deaths to the number of inhabitants per state, on average, this values was found to be below 0.15%.
